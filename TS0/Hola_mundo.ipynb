# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="250" />
#
# #### Teoría de Circuitos II - R4001
# # ¡Hola Mundo!
# #### Benjamín Ithurburu

# %% [markdown]
# Se realizará el análisis del siguiente filtro:
# \begin{equation}
# H(s) = \frac{\omega_0^2}{s^2+s\frac{\omega_0}{Q}+\omega_0^2}
# \tag{1}
# \end{equation}
#
# Con parámetros $\omega_0=1\frac{rad}{seg}$ y $Q=\frac{\sqrt{2}}{2}$

# %%
# Se incluye la librería pytc2
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

# módulos numéricos y de funciones científicas
from scipy.signal import TransferFunction
import numpy as np
import matplotlib.pyplot as plt

# %%
# Configuración de parámetros para fijar estilo de gráficos en notebook. 
# Con el objetivo de que el tamaño de salida, sea adecuado al jubyter notebook.
# (Solo utilizar en notebooks)

#%% Inicialización de librerías

# Para eliminar bugs:
plt.figure(1)
plt.close(1)

import matplotlib as mpl

fig_sz_x = 15
fig_sz_y = 10
fig_dpi = 80
fig_front_size = 15

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_front_size})

#%% Fin - Inicialización de librerías

# %%
# Código para análisis del filtro
w0 = 1
Q = np.sqrt(2)/2

# Obtención de función transferencia
my_tf = TransferFunction([w0**2],[1, w0/Q, w0**2])

# Gráfico Bode
bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(Q))

# Gráfico de Polos y Ceros
pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(Q))

# Group Delay
GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(Q))
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# #### **Conclusión:**
# Se realizaron modificaciones en el tamaño de los gráficos, con el objetivo de obtener una visualización *estilizada*.
# Así mismo, se buscó centrar los gráficos por medio de diferentes funciones, aunque sin obtener resultados satisfactorios.
